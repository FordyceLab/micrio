# %% [markdown]
# # SETUP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as disp
import time
import concurrent.futures

from acqpack import Manifold, Mfcs
from acqpack import Motor, AsiController, Autosampler, FractionCollector
from acqpack import utils as ut
from acqpack import gui
from acqpack import Log

l = Log()
l.track_classes([Manifold, Mfcs, Autosampler, FractionCollector]) # only call once
l.show_filter = '''~(cl=='Manifold')'''

# %% [markdown]
# ### Manifold + Device Control
# - **Device**: MITOMI (inlet bus only)
# - **bank_0-7**: 32psi, filled with water
#     - **chip control** as in `valvemap.txt`: Tygon
# - **bank_8-15**: 32psi, __8__ filled with water, **9** filled with air

# %%
m = Manifold("192.168.1.2", 'config/run/valvemap.txt')
# gui.manifold_control(m)
m.valvemap.query('name!=" "')

@l.track_fn
def open_waste():
    for i in range(5):
        m.open('valve',i)
        time.sleep(.25)
    
@l.track_fn
def close_waste():
    for i in range(4,-1,-1):
        m.close('valve',i)
        time.sleep(.25)
        
m.open_waste = open_waste
m.close_waste = close_waste

# %% [markdown]
# ### MFCS + Device Flow
# - __mfcs[1]__ to __125ml Nalgene-PETG reservoir (water)__: Tygon
# - __125ml Nalgene-PETG reservoir filled (water)__ to __device[in5]__: Tygon
# - __mfcs[2]__ to __autosampler\[headspace-needle\]__ : Tygon
# - __autosampler[sample-needle]__ to __device[in6]__: PEEK tubing, 65 um dia-in, 500 um dia-out, 35 cm len
# - __device[in7]__ to __collector[dropper]__: PEEK tubing, 65 um dia-in, 500 um dia-out, 35 cm len
# - __manifold[9]__ to __collector[sheath]__: Tygon
# - __device[in4]__ to __50ml conical (empty)__: Tygon

# %%
p = Mfcs('config/system/mfcs.yaml', 'config/run/chanmap.txt')
p.chanmap
# Out:
# MFCS initialized. SN: 758
# PID alpha: 2
# Pressure units: psi
#    channel    inlet
# 0        0      all
# 1        1     wash
# 2        2  sampler
# 3        3
# 4        4

# %% [markdown]
# ### Autosampler

# %%
a = Autosampler(Motor('config/system/sampler-motor.yaml'),  AsiController('config/system/sampler-asi.yaml'))
a.add_frame('wash', 'config/system/sampler-deck.txt', 'config/run/sampler-4scint.txt')
a.add_frame('plate', 'config/system/sampler-deck.txt', 'config/run/sampler-96well.txt')
a.zh_travel = 37 # hardware safe travel height
gui.stage_control(a)
# Out:
# (0.000, 0.000, 0.000) hardware
# (0.330, -28.698, 99.600) wash
# (0.330, -28.698, 99.600) plate

# %% [markdown]
# ### Fraction Collector

# %%
f = FractionCollector(AsiController('config/system/collector-asi.yaml'))
f.add_frame('plate', 'config/system/collector-deck.txt', 'config/run/collector-96well.txt')
gui.stage_control(f)
# Out:
# (0.000, 0.000) hardware
# (0.000, 0.000) plate

# %% [markdown]
# ### Micromanager
# - run in `microscopy.ipynb`

# %%
start_checklist = '''
Fluid Levels -------------------
- Scint Vials
- Wash-In Vessel
- Waste Vial
- Plates

Manifold -----------------------
- Valves: 35psi, reservoir full
- Sheath: 35psi, reservoir empty
-   MFCS: 17psi (<=1300 mbar)

Scope --------------------------
- ROI
- HAL off
- LED 100% 590nm, FL open
- Acq Running

Press ENTER to start run
'''

end_checklist = '''
Fluid Levels -------------------
- Plates: remove

Manifold -----------------------
- Valves: 25psi

Scope --------------------------
- LED off
- HAL off
'''

# %% [markdown]
# # SCRIPT

# %% [raw]
# Resources:
# # a
# # f
# # m[wash,sampler,waste,collector]
# # p[wash,sampler]
#
# # select needed resources above (other resources 'floating')
# # i.e. this function cares about the state of...
# # prepare state
#
# # beware of conflicting resource states between threads!!!!

# %%
@l.track_fn
def simul(fargs):
    with concurrent.futures.ThreadPoolExecutor(max_workers=len(fargs)) as executor:
        for f,args in fargs.iteritems():
            executor.submit(f, *args)

simul({a.goto: ('wash', 'contents', 'waste'),
       f.goto: ('plate','series','waste')})

# %%
p_low_sampler = .1
p_low = 1.5
p_high = 15

@l.track_fn
def idle():
    m_idle()
    p_idle()
    simul({a.home:(),
           f.goto:('plate','series','waste')})
    sheath()
    
def m_idle():
    m.close('outlet', 'collector')
    m.close('inlet','sampler')
    m.close('inlet','wash')
    m.close_waste()
    m.open('name','sheath') # depressurize
    m.close('name','in')
    
def p_idle():
    p.set('inlet','sampler', p_low_sampler)
    p.set('inlet','wash', p_low)

# def from_wash():
#     pass

# def from_sampler():
#     pass

@l.track_fn  
def to_waste(sec):
    m.open_waste()
    time.sleep(sec)
    m.close_waste()
    
@l.track_fn  
def to_sampler(sec):
    m.open('outlet','sampler')
    time.sleep(sec)
    m.close('outlet','sampler')
    
@l.track_fn  
def to_collector(sec, use_sheath=True):
    m.open('outlet','collector')
    if use_sheath:
        sheath(sec)
    else:
        time.sleep(sec)
    m.close('outlet','collector') 

@l.track_fn    
def needle_wash():
    a.goto('wash', 'contents', 'etoh')
    for _ in range(4):
        a.Z.move_relative(-3.)
        a.Z.move_relative(3.)
    a.goto('wash', 'contents', 'water')
    for _ in range(4):
        a.Z.move_relative(-3.)
        a.Z.move_relative(3.)

@l.track_fn
def sheath(sec=0):
    sheath_period = 28
    sheath_length = .09
    
    if sec>0:
        t_end = time.time() + sec
        while time.time() < t_end-sheath_period-sheath_length-.1:
                time.sleep(sheath_period)
                m.close('name','sheath')
                time.sleep(sheath_length)
                m.open('name','sheath')
        time.sleep(t_end-time.time())
        
    m.close('name','sheath')
    time.sleep(sheath_length)
    m.open('name','sheath')

# %%
@l.track_fn
def prime(well_in, sec_waste=175, sec_collector=55):
    a.goto('plate', 'well', well_in['well'])
    p.set('inlet', 'sampler', p_high)
    m.open('inlet','sampler')
    
    to_waste(sec_waste)
    to_collector(sec_collector, use_sheath)

@l.track_fn
def collect(well_out, sec=60*3.88):
    f.goto('plate','well', well_out['well'])
    to_collector(sec, use_sheath)
    
    p.set('inlet','sampler', p_low_sampler)
    time.sleep(1) # give sampler pressure time to decrease
    m.close('inlet','sampler')
    
@l.track_fn
def flush(sec_waste=40, sec_sampler=60*3.75, sec_collector=60*3.75, sec_air_purge=4):
    m.open('inlet', 'wash')
    p.set('inlet','wash', p_high)

    simul({to_waste:(sec_waste,),
           a.goto:('wash', 'contents', 'waste'),
           f.goto:('plate','well', well_waste)})
    
    simul({to_sampler:(sec_sampler,),
           to_collector:(sec_collector, use_sheath)})
    
    if use_needle_wash:
        simul({needle_wash:(),
               time.sleep:(sec_air_purge,)})
    
    p.set('inlet','wash', p_low)
    m.close('inlet','wash')
    
# DEVICE CLASS
# think of flow graph / flow path through graph
# set node(inlet(s) + outlet(s)) parameters, connection matrix
# instead of m.open()/m.close(), hold valves open for lengths of time? optional m.open(sec=0)?

# %%
@l.track_fn
def setup(show_checklist=True, sec_air_purge=20):
    if show_checklist:
        raw_input(start_checklist)
        disp.clear_output()

    idle()
    flush(20,60,60,sec_air_purge)
    l.show()
    
@l.track_fn
def iteration(well_in, well_out):
    prime(well_in)
    l.show()
    collect(well_out)
    l.show()
    flush()
    l.show()
    
@l.track_fn
def cleanup(show_checklist=True):    
    flush(20,60,60)
    idle()
    
    if show_checklist:
        print end_checklist
        
    # save
    ts = time.strftime("%Y%m%d-%H%M", time.localtime())
    l.df.to_csv('data/{}_log.csv'.format(ts), index=False, header=True) # log
    
    l.show()
    l.write('DONE')

# %% [markdown]
# # Run --------------------------------------

# %%
q = '''well.str.contains('B|C|D|E')'''
# q = '''well in ['C01','C03']'''

map_in = (a.frames.plate.position_table
          .query(q)
          .sort_index(ascending=True).reset_index())
map_out = (f.frames.plate.position_table
           .query(q)
           .sort_index(ascending=True).reset_index())

disp.display(map_in)
disp.display(map_out)
# Out:
#     index   n   s  r   c well   series  conc_fluorophore      conc_dna  \
# 0      12  12  23  1   0  B01     +n-s      0.000000e+00  0.000000e+00
# 1      13  13  22  1   1  B02     +n-s      0.000000e+00  0.000000e+00
# 2      14  14  21  1   2  B03     +n-s      2.500000e-05  1.000000e-12
# 3      15  15  20  1   3  B04     +n-s      0.000000e+00  0.000000e+00
# 4      16  16  19  1   4  B05     +n-s      0.000000e+00  0.000000e+00
# 5      17  17  18  1   5  B06     +n-s      2.500000e-05  1.000000e-12
# 6      18  18  17  1   6  B07     +n-s      0.000000e+00  0.000000e+00
# 7      19  19  16  1   7  B08     +n-s      0.000000e+00  0.000000e+00
# 8      20  20  15  1   8  B09     +n-s      2.500000e-05  1.000000e-12
# 9      21  21  14  1   9  B10     +n-s      0.000000e+00  0.000000e+00
# 10     22  22  13  1  10  B11     +n-s      2.500000e-05  1.000000e-12
# 11     23  23  12  1  11  B12     +n-s      0.000000e+00  0.000000e+00
# 12     24  24  24  2   0  C01     +n+s      0.000000e+00  0.000000e+00
# 13     25  25  25  2   1  C02     +n+s      0.000000e+00  0.000000e+00
# 14     26  26  26  2   2  C03     +n+s      2.500000e-05  1.000000e-12
# 15     27  27  27  2   3  C04     +n+s      0.000000e+00  0.000000e+00
# 16     28  28  28  2   4  C05     +n+s      0.000000e+00  0.000000e+00
# 17     29  29  29  2   5  C06     +n+s      2.500000e-05  1.000000e-12
# 18     30  30  30  2   6  C07     +n+s      0.000000e+00  0.000000e+00
# 19     31  31  31  2   7  C08     +n+s      0.000000e+00  0.000000e+00
# 20     32  32  32  2   8  C09     +n+s      2.500000e-05  1.000000e-12
# 21     33  33  33  2   9  C10     +n+s      0.000000e+00  0.000000e+00
# 22     34  34  34  2  10  C11     +n+s      2.500000e-05  1.000000e-12
# 23     35  35  35  2  11  C12     +n+s      0.000000e+00  0.000000e+00
# 24     36  36  47  3   0  D01     -n+s      0.000000e+00  0.000000e+00
# 25     37  37  46  3   1  D02     -n+s      0.000000e+00  0.000000e+00
# 26     38  38  45  3   2  D03     -n+s      2.500000e-05  1.000000e-12
# 27     39  39  44  3   3  D04     -n+s      0.000000e+00  0.000000e+00
# 28     40  40  43  3   4  D05     -n+s      0.000000e+00  0.000000e+00
# 29     41  41  42  3   5  D06     -n+s      2.500000e-05  1.000000e-12
# 30     42  42  41  3   6  D07     -n+s      0.000000e+00  0.000000e+00
# 31     43  43  40  3   7  D08     -n+s      0.000000e+00  0.000000e+00
# 32     44  44  39  3   8  D09     -n+s      2.500000e-05  1.000000e-12
# 33     45  45  38  3   9  D10     -n+s      0.000000e+00  0.000000e+00
# 34     46  46  37  3  10  D11     -n+s      2.500000e-05  1.000000e-12
# 35     47  47  36  3  11  D12     -n+s      0.000000e+00  0.000000e+00
# 36     48  48  48  4   0  E01  std-int      0.000000e+00  0.000000e+00
# 37     49  49  49  4   1  E02  std-int      0.000000e+00  0.000000e+00
# 38     50  50  50  4   2  E03  std-int      1.280000e-11  5.120000e-19
# 39     51  51  51  4   3  E04  std-int      6.400000e-11  2.560000e-18
# 40     52  52  52  4   4  E05  std-int      3.200000e-10  1.280000e-17
# 41     53  53  53  4   5  E06  std-int      1.600000e-09  6.400000e-17
# 42     54  54  54  4   6  E07  std-int      8.000000e-09  3.200000e-16
# 43     55  55  55  4   7  E08  std-int      4.000000e-08  1.600000e-15
# 44     56  56  56  4   8  E09  std-int      2.000000e-07  8.000000e-15
# 45     57  57  57  4   9  E10  std-int      1.000000e-06  4.000000e-14
# 46     58  58  58  4  10  E11  std-int      5.000000e-06  2.000000e-13
# 47     59  59  59  4  11  E12  std-int      2.500000e-05  1.000000e-12
#
#         vol  amt_fluorophore       amt_dna  needle_wash  sheath        x  \
# 0   0.00003     0.000000e+00  0.000000e+00          1.0     1.0    2.493
# 1   0.00003     0.000000e+00  0.000000e+00          1.0     1.0   11.493
# 2   0.00003     7.500000e-10  3.000000e-17          1.0     0.0   20.493
# 3   0.00003     0.000000e+00  0.000000e+00          1.0     0.0   29.493
# 4   0.00003     0.000000e+00  0.000000e+00          1.0     0.0   38.493
# 5   0.00003     7.500000e-10  3.000000e-17          1.0     0.0   47.493
# 6   0.00003     0.000000e+00  0.000000e+00          1.0     0.0   56.493
# 7   0.00003     0.000000e+00  0.000000e+00          1.0     0.0   65.493
# 8   0.00003     7.500000e-10  3.000000e-17          1.0     0.0   74.493
# 9   0.00003     0.000000e+00  0.000000e+00          1.0     0.0   83.493
# 10  0.00003     7.500000e-10  3.000000e-17          1.0     0.0   92.493
# 11  0.00003     0.000000e+00  0.000000e+00          1.0     0.0  101.493
# 12  0.00003     0.000000e+00  0.000000e+00          1.0     1.0    2.493
# 13  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   11.493
# 14  0.00003     7.500000e-10  3.000000e-17          1.0     1.0   20.493
# 15  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   29.493
# 16  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   38.493
# 17  0.00003     7.500000e-10  3.000000e-17          1.0     1.0   47.493
# 18  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   56.493
# 19  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   65.493
# 20  0.00003     7.500000e-10  3.000000e-17          1.0     1.0   74.493
# 21  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   83.493
# 22  0.00003     7.500000e-10  3.000000e-17          1.0     1.0   92.493
# 23  0.00003     0.000000e+00  0.000000e+00          1.0     1.0  101.493
# 24  0.00003     0.000000e+00  0.000000e+00          1.0     1.0    2.493
# 25  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   11.493
# 26  0.00003     7.500000e-10  3.000000e-17          0.0     1.0   20.493
# 27  0.00003     0.000000e+00  0.000000e+00          0.0     1.0   29.493
# 28  0.00003     0.000000e+00  0.000000e+00          0.0     1.0   38.493
# 29  0.00003     7.500000e-10  3.000000e-17          0.0     1.0   47.493
# 30  0.00003     0.000000e+00  0.000000e+00          0.0     1.0   56.493
# 31  0.00003     0.000000e+00  0.000000e+00          0.0     1.0   65.493
# 32  0.00003     7.500000e-10  3.000000e-17          0.0     1.0   74.493
# 33  0.00003     0.000000e+00  0.000000e+00          0.0     1.0   83.493
# 34  0.00003     7.500000e-10  3.000000e-17          0.0     1.0   92.493
# 35  0.00003     0.000000e+00  0.000000e+00          0.0     1.0  101.493
# 36  0.00003     0.000000e+00  0.000000e+00          1.0     1.0    2.493
# 37  0.00003     0.000000e+00  0.000000e+00          1.0     1.0   11.493
# 38  0.00003     3.840000e-16  1.540000e-23          1.0     1.0   20.493
# 39  0.00003     1.920000e-15  7.680000e-23          1.0     1.0   29.493
# 40  0.00003     9.600000e-15  3.840000e-22          1.0     1.0   38.493
# 41  0.00003     4.800000e-14  1.920000e-21          1.0     1.0   47.493
# 42  0.00003     2.400000e-13  9.600000e-21          1.0     1.0   56.493
# 43  0.00003     1.200000e-12  4.800000e-20          1.0     1.0   65.493
# 44  0.00003     6.000000e-12  2.400000e-19          1.0     1.0   74.493
# 45  0.00003     3.000000e-11  1.200000e-18          1.0     1.0   83.493
# 46  0.00003     1.500000e-10  6.000000e-18          1.0     1.0   92.493
# 47  0.00003     7.500000e-10  3.000000e-17          1.0     1.0  101.493
#
#          y     z
# 0   21.749 -0.85
# 1   21.749 -0.85
# 2   21.749 -0.85
# 3   21.749 -0.85
# 4   21.749 -0.85
# 5   21.749 -0.85
# 6   21.749 -0.85
# 7   21.749 -0.85
# 8   21.749 -0.85
# 9   21.749 -0.85
# 10  21.749 -0.85
# 11  21.749 -0.85
# 12  30.749 -0.85
# 13  30.749 -0.85
# 14  30.749 -0.85
# 15  30.749 -0.85
# 16  30.749 -0.85
# 17  30.749 -0.85
# 18  30.749 -0.85
# 19  30.749 -0.85
# 20  30.749 -0.85
# 21  30.749 -0.85
# 22  30.749 -0.85
# 23  30.749 -0.85
# 24  39.749 -0.85
# 25  39.749 -0.85
# 26  39.749 -0.85
# 27  39.749 -0.85
# 28  39.749 -0.85
# 29  39.749 -0.85
# 30  39.749 -0.85
# 31  39.749 -0.85
# 32  39.749 -0.85
# 33  39.749 -0.85
# 34  39.749 -0.85
# 35  39.749 -0.85
# 36  48.749 -0.85
# 37  48.749 -0.85
# 38  48.749 -0.85
# 39  48.749 -0.85
# 40  48.749 -0.85
# 41  48.749 -0.85
# 42  48.749 -0.85
# 43  48.749 -0.85
# 44  48.749 -0.85
# 45  48.749 -0.85
# 46  48.749 -0.85
# 47  48.749 -0.85
#     index   n   s  r   c well well_waste   series  conc_fluorophore  \
# 0      12  12  23  1   0  B01        A01     +n-s      0.000000e+00
# 1      13  13  22  1   1  B02        A02     +n-s      0.000000e+00
# 2      14  14  21  1   2  B03        A03     +n-s      2.500000e-05
# 3      15  15  20  1   3  B04        A04     +n-s      0.000000e+00
# 4      16  16  19  1   4  B05        A05     +n-s      0.000000e+00
# 5      17  17  18  1   5  B06        A06     +n-s      2.500000e-05
# 6      18  18  17  1   6  B07        A07     +n-s      0.000000e+00
# 7      19  19  16  1   7  B08        A08     +n-s      0.000000e+00
# 8      20  20  15  1   8  B09        A09     +n-s      2.500000e-05
# 9      21  21  14  1   9  B10        A10     +n-s      0.000000e+00
# 10     22  22  13  1  10  B11        A11     +n-s      2.500000e-05
# 11     23  23  12  1  11  B12        A12     +n-s      0.000000e+00
# 12     24  24  24  2   0  C01        A01     +n+s      0.000000e+00
# 13     25  25  25  2   1  C02        A02     +n+s      0.000000e+00
# 14     26  26  26  2   2  C03        A03     +n+s      2.500000e-05
# 15     27  27  27  2   3  C04        A04     +n+s      0.000000e+00
# 16     28  28  28  2   4  C05        A05     +n+s      0.000000e+00
# 17     29  29  29  2   5  C06        A06     +n+s      2.500000e-05
# 18     30  30  30  2   6  C07        A07     +n+s      0.000000e+00
# 19     31  31  31  2   7  C08        A08     +n+s      0.000000e+00
# 20     32  32  32  2   8  C09        A09     +n+s      2.500000e-05
# 21     33  33  33  2   9  C10        A10     +n+s      0.000000e+00
# 22     34  34  34  2  10  C11        A11     +n+s      2.500000e-05
# 23     35  35  35  2  11  C12        A12     +n+s      0.000000e+00
# 24     36  36  47  3   0  D01        A01     -n+s      0.000000e+00
# 25     37  37  46  3   1  D02        A02     -n+s      0.000000e+00
# 26     38  38  45  3   2  D03        A03     -n+s      2.500000e-05
# 27     39  39  44  3   3  D04        A04     -n+s      0.000000e+00
# 28     40  40  43  3   4  D05        A05     -n+s      0.000000e+00
# 29     41  41  42  3   5  D06        A06     -n+s      2.500000e-05
# 30     42  42  41  3   6  D07        A07     -n+s      0.000000e+00
# 31     43  43  40  3   7  D08        A08     -n+s      0.000000e+00
# 32     44  44  39  3   8  D09        A09     -n+s      2.500000e-05
# 33     45  45  38  3   9  D10        A10     -n+s      0.000000e+00
# 34     46  46  37  3  10  D11        A11     -n+s      2.500000e-05
# 35     47  47  36  3  11  D12        A12     -n+s      0.000000e+00
# 36     48  48  48  4   0  E01        A01  std-int      0.000000e+00
# 37     49  49  49  4   1  E02        A02  std-int      0.000000e+00
# 38     50  50  50  4   2  E03        A03  std-int      1.280000e-11
# 39     51  51  51  4   3  E04        A04  std-int      6.400000e-11
# 40     52  52  52  4   4  E05        A05  std-int      3.200000e-10
# 41     53  53  53  4   5  E06        A06  std-int      1.600000e-09
# 42     54  54  54  4   6  E07        A07  std-int      8.000000e-09
# 43     55  55  55  4   7  E08        A08  std-int      4.000000e-08
# 44     56  56  56  4   8  E09        A09  std-int      2.000000e-07
# 45     57  57  57  4   9  E10        A10  std-int      1.000000e-06
# 46     58  58  58  4  10  E11        A11  std-int      5.000000e-06
# 47     59  59  59  4  11  E12        A12  std-int      2.500000e-05
#
#         conc_dna  ...  amt_fluorophore       amt_dna  needle_wash  sheath  \
# 0   0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 1   0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 2   1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     0.0
# 3   0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     0.0
# 4   0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     0.0
# 5   1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     0.0
# 6   0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     0.0
# 7   0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     0.0
# 8   1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     0.0
# 9   0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     0.0
# 10  1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     0.0
# 11  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     0.0
# 12  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 13  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 14  1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     1.0
# 15  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 16  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 17  1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     1.0
# 18  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 19  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 20  1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     1.0
# 21  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 22  1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     1.0
# 23  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 24  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 25  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 26  1.000000e-12  ...     2.500000e-17  1.000000e-24          0.0     1.0
# 27  0.000000e+00  ...     0.000000e+00  0.000000e+00          0.0     1.0
# 28  0.000000e+00  ...     0.000000e+00  0.000000e+00          0.0     1.0
# 29  1.000000e-12  ...     2.500000e-17  1.000000e-24          0.0     1.0
# 30  0.000000e+00  ...     0.000000e+00  0.000000e+00          0.0     1.0
# 31  0.000000e+00  ...     0.000000e+00  0.000000e+00          0.0     1.0
# 32  1.000000e-12  ...     2.500000e-17  1.000000e-24          0.0     1.0
# 33  0.000000e+00  ...     0.000000e+00  0.000000e+00          0.0     1.0
# 34  1.000000e-12  ...     2.500000e-17  1.000000e-24          0.0     1.0
# 35  0.000000e+00  ...     0.000000e+00  0.000000e+00          0.0     1.0
# 36  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 37  0.000000e+00  ...     0.000000e+00  0.000000e+00          1.0     1.0
# 38  5.120000e-19  ...     6.550000e-30  2.620000e-37          1.0     1.0
# 39  2.560000e-18  ...     1.640000e-28  6.550000e-36          1.0     1.0
# 40  1.280000e-17  ...     4.100000e-27  1.640000e-34          1.0     1.0
# 41  6.400000e-17  ...     1.020000e-25  4.100000e-33          1.0     1.0
# 42  3.200000e-16  ...     2.560000e-24  1.020000e-31          1.0     1.0
# 43  1.600000e-15  ...     6.400000e-23  2.560000e-30          1.0     1.0
# 44  8.000000e-15  ...     1.600000e-21  6.400000e-29          1.0     1.0
# 45  4.000000e-14  ...     4.000000e-20  1.600000e-27          1.0     1.0
# 46  2.000000e-13  ...     1.000000e-18  4.000000e-26          1.0     1.0
# 47  1.000000e-12  ...     2.500000e-17  1.000000e-24          1.0     1.0
#
#           x       y     z  intensity plate_reader qpcr
# 0     2.493  21.749 -0.85        NaN          NaN  NaN
# 1    11.493  21.749 -0.85        NaN          NaN  NaN
# 2    20.493  21.749 -0.85        NaN          NaN  NaN
# 3    29.493  21.749 -0.85        NaN          NaN  NaN
# 4    38.493  21.749 -0.85        NaN          NaN  NaN
# 5    47.493  21.749 -0.85        NaN          NaN  NaN
# 6    56.493  21.749 -0.85        NaN          NaN  NaN
# 7    65.493  21.749 -0.85        NaN          NaN  NaN
# 8    74.493  21.749 -0.85        NaN          NaN  NaN
# 9    83.493  21.749 -0.85        NaN          NaN  NaN
# 10   92.493  21.749 -0.85        NaN          NaN  NaN
# 11  101.493  21.749 -0.85        NaN          NaN  NaN
# 12    2.493  30.749 -0.85        NaN          NaN  NaN
# 13   11.493  30.749 -0.85        NaN          NaN  NaN
# 14   20.493  30.749 -0.85        NaN          NaN  NaN
# 15   29.493  30.749 -0.85        NaN          NaN  NaN
# 16   38.493  30.749 -0.85        NaN          NaN  NaN
# 17   47.493  30.749 -0.85        NaN          NaN  NaN
# 18   56.493  30.749 -0.85        NaN          NaN  NaN
# 19   65.493  30.749 -0.85        NaN          NaN  NaN
# 20   74.493  30.749 -0.85        NaN          NaN  NaN
# 21   83.493  30.749 -0.85        NaN          NaN  NaN
# 22   92.493  30.749 -0.85        NaN          NaN  NaN
# 23  101.493  30.749 -0.85        NaN          NaN  NaN
# 24    2.493  39.749 -0.85        NaN          NaN  NaN
# 25   11.493  39.749 -0.85        NaN          NaN  NaN
# 26   20.493  39.749 -0.85        NaN          NaN  NaN
# 27   29.493  39.749 -0.85        NaN          NaN  NaN
# 28   38.493  39.749 -0.85        NaN          NaN  NaN
# 29   47.493  39.749 -0.85        NaN          NaN  NaN
# 30   56.493  39.749 -0.85        NaN          NaN  NaN
# 31   65.493  39.749 -0.85        NaN          NaN  NaN
# 32   74.493  39.749 -0.85        NaN          NaN  NaN
# 33   83.493  39.749 -0.85        NaN          NaN  NaN
# 34   92.493  39.749 -0.85        NaN          NaN  NaN
# 35  101.493  39.749 -0.85        NaN          NaN  NaN
# 36    2.493  48.749 -0.85        NaN          NaN  NaN
# 37   11.493  48.749 -0.85        NaN          NaN  NaN
# 38   20.493  48.749 -0.85        NaN          NaN  NaN
# 39   29.493  48.749 -0.85        NaN          NaN  NaN
# 40   38.493  48.749 -0.85        NaN          NaN  NaN
# 41   47.493  48.749 -0.85        NaN          NaN  NaN
# 42   56.493  48.749 -0.85        NaN          NaN  NaN
# 43   65.493  48.749 -0.85        NaN          NaN  NaN
# 44   74.493  48.749 -0.85        NaN          NaN  NaN
# 45   83.493  48.749 -0.85        NaN          NaN  NaN
# 46   92.493  48.749 -0.85        NaN          NaN  NaN
# 47  101.493  48.749 -0.85        NaN          NaN  NaN
#
# [48 rows x 21 columns]

# %%
use_sheath, use_needle_wash, well_waste  = True, True, 'A01'
setup()
for (i, well_in), (j, well_out) in zip(map_in.iterrows(), map_out.iterrows()):
    use_sheath, use_needle_wash, well_waste = well_in.sheath, well_in.needle_wash, well_out.well_waste
    iteration(well_in, well_out)

use_sheath, use_needle_wash, well_waste  = True, True, 'A12'
cleanup()
l.write('DONE')
# Out:
# <style  type="text/css" >
#     #T_cfcdee80_d0d2_11e9_b392_94c6917a54da th {
#           text-align: left;
#     }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow0_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow1_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow2_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow3_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow4_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow5_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow6_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow7_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow8_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col2 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col3 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col4 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col5 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col6 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow9_col7 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow10_col0 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow10_col1 {
#             text-align:  left;
#         }    #T_cfcdee80_d0d2_11e9_b392_94c6917a54darow10_col2 {
#             text-align:  left;
#         }

# %% [markdown]
# # Shutdown

# %%
del p

# %% [markdown]
# # ---------------

# %%
s = '2h I X\r'
# s = '2h S X=7.3 Y=7.3\r'

a.XY.serial.write(s)
time.sleep(.5)
resp = a.XY.serial.read(a.XY.serial.in_waiting)
print resp.replace('\r','\n\r')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import IPython.display as disp
df = pd.read_csv('temp.csv').fillna('')
df['in'] = df['in'].apply(lambda x: tuple(y for y in x.replace('(','').replace(')','').split(', ')))

# vlines label
def plot(dd):
    plt.figure(figsize=(15,3))
    yt=[]
    for i,row in pd.DataFrame(dd.groupby('name')).iterrows():
        yt.append(row[0])
        for j,(x0,x1,s) in enumerate(zip(row[1].t_in - t0, row[1].t_out - t0, row[1]['fn'])):
            y0=i+j*0
            plt.vlines(x0, y0+.25,y0, color='green', lw=.4)
            plt.hlines(y0, x0,x1, color='b', lw=1)
            plt.vlines(x1, y0,y0-.25, color='red', lw=.4)
            plt.annotate(xy=(x0+.2,y0+.02),s=s)
    plt.yticks(np.arange(len(yt)), yt)
    plt.show()

# %%
t0 = df.t_in.min()
yt = []
for _,c in pd.DataFrame(df.query('fn!="sheath"')
                        .query('fn!="pressurize"')
                        .query('fn!="depressurize"')
                        .query('fn!="read_valve"')
                        .groupby('class')).iterrows():
    
    dd=c[1]
    
    if c[0]=='':
        dd['name'] = dd['fn']
        plot(dd)
    
#     if c[0]=='Autosampler':
#         dd['name'] = 'move'
#         plot(dd)

#     if c[0]=='FractionCollector':
#         dd['name'] = 'move'
#         plot(dd)
        
#     if c[0]=='Manifold':
#         dd = dd.dropna()
#         dd=dd[dd['in'].apply(lambda x: 'r'!=x[-1][1])]
#         dd['name'] = dd['in'].apply(lambda x: x[-1].replace('\'',''))
#         dd = dd.query('name!="sheath"')
#         plot(dd)

#     if c[0]=='Mfcs':
#         dd['name'] = dd['in'].apply(lambda x: x[1].replace('\'',''))
#         plot(dd)

# %%
def plot(dd):
    plt.figure(figsize=(15,3))
    yt=[]
    for i,row in pd.DataFrame(dd.groupby(['name','class'])).iterrows():
        yt.append(row[0])
        for j,(x0,x1,s) in enumerate(zip(row[1].t_in - t0, row[1].t_out - t0, row[1]['fn'])):
            y0=i+j*0
            plt.vlines(x0, y0+.25,y0, color='green', lw=.4)
            plt.hlines(y0, x0,x1, color='b', lw=1)
            plt.vlines(x1, y0,y0-.25, color='red', lw=.4)
            plt.annotate(xy=(x0+.2,y0+.02),s=s)
    plt.yticks(np.arange(len(yt)), yt)
    plt.show()

t0 = l.df.t_in.min()
yt = []
dd = l.df 
dd['name'] = dd['th']
plot(dd)

# %%
# %matplotlib tk

# %%
# Timing test
m.close('inlet','wash')
p.set('inlet','wash', 2)

p.set('inlet','sampler',.2)
a.goto('plate','well', 'B03')
p.set('inlet','sampler',15.5)
m.open('inlet','sampler')

# prime sampler
m.open_waste()
time.sleep(155)
# t0 = time.time()
# raw_input('note: fluorescence plateaus')
# print 'prime sampler', time.time()-t0
m.close_waste()

# prime collector
m.open('outlet','collector')
t0 = time.time()
raw_input('note: color at outlet')
print 'prime collector', time.time()-t0
m.close('outlet','collector')

m.close('inlet', 'sampler')
p.set('inlet','sampler',.2)
time.sleep(.2)
a.goto('wash','contents', 'waste')

p.set('inlet','wash', 16)
m.open('inlet','wash')

m.open_waste()
time.sleep(10)
m.close_waste()

# flush sampler + collector
m.open('outlet','sampler')
m.open('outlet','collector')
t0 = time.time()
raw_input('note: clear at needle')
print 'flush sampler + collector (sampler)', time.time()-t0
m.close('outlet','sampler')
m.close('outlet','collector')

# %%
m.open('outlet','collector')
sheath(3.88*60)
m.close('outlet','collector')
